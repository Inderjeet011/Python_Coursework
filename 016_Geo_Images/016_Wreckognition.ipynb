# %% [markdown]
# # Wreckognition

# %% [markdown]
# In this section, we will see a few examples of:
# * geographic tools
# * using numpy to manipulate images
# * applying image filters
# * segmentation
# * ML-style clustering

# %% [markdown]
# We will use DAERA's list of protected shipwrecks, hosted by OpenDataNI. For more information, see the [page on their site](https://www.opendatani.gov.uk/dataset/protected-wreck-sites).

# %% [markdown]
# Using these tools, we hope to answer the questions:
#
# > Do wrecks cluster near groups of ports?
#
# and
#
# > Are wrecks more common in deep water or shallow water?

# %% [markdown]
# We may even try to see whether shipwrecks in the 1800s, 1900s or 2000s have different likely locations.

# %% [markdown]
# To begin, we will open up the downloaded dataset using geopandas - this is an extended version of pandas that can attach geographic (or geometric) attributes to each row.

# %% [markdown]
# ## Geopandas

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('/content/protected_wrecks.geojson')

# %%
gdf
# Out:
#                    Name   Date_lost                              Type  \
# 0                 Ailsa  26/02/1892               Steamship (British)
# 1      (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)
# 2         Albia (poss.)  28/09/1929             Spanish tramp steamer
# 3                Alcedo  ??/01/1892                     Steam coaster
# 4                 Alder        None                              None
# ..                  ...         ...                               ...
# 335             Unknown        None                             Wreck
# 336  Vought F4U Corsair  09/10/1944                          Aircraft
# 337             Unknown        None                             Wreck
# 338             Unknown        None                             Wreck
# 339         HMS Curacao  02/10/1942             C-Class light cruiser
#
#           Cargo   Depth   Position_q  \
# 0       General    1-5m   Reasonable
# 1          None  10-23m     Accurate
# 2    Copper ore     10m  Approximate
# 3          Coal      7m  Approximate
# 4          None     -3m  Approximate
# ..          ...     ...          ...
# 335        None    None     Accurate
# 336        None    None  Approximate
# 337        None    125m     Accurate
# 338        None    139m     Accurate
# 339        None    None         None
#
#                                              Condition             Ref Status  \
# 0            Badly broken up, part of wreck is onshore  UKHO, IRW, CMA   LIVE
# 1    Llargely intact with upright funnel. Wooden de...  UKHO, IRW, CMA   LIVE
# 2                                    5m high, upright.  IRW, UKHO, CMA   LIVE
# 3                           2.5m high, badly broken up        IRW, CMA   LIVE
# 4                                                 None            UKHO   LIFT
# ..                                                 ...             ...    ...
# 335  Concentraion of possible ships timbers protrud...        MFD 2016   None
# 336                                           Wreckage        MFD 2017   None
# 337  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 338  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 339                                               None            None   None
#
#                                                Notes  ...   X_Coord  \
# 0                                               None  ... -5.738217
# 1                                               None  ... -5.629383
# 2                                               None  ... -5.741317
# 3                                               None  ... -5.696200
# 4                                 Wreck removed 1938  ... -6.098500
# ..                                               ...  ...       ...
# 335        Observed during foreshore survey 08/11/16  ... -6.208401
# 336    Vought F4U Corsair fighter (serial no. JT693)  ... -7.040083
# 337  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 338  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 339                                             None  ...  0.000000
#
#        Y_Coord    Updated  Nation   How_lost  \
# 0    54.852500        NaT    None       None
# 1    54.451550        NaT    None       None
# 2    54.949933        NaT    None       None
# 3    54.815483        NaT    None       None
# 4    54.053217        NaT    None       None
# ..         ...        ...     ...        ...
# 335  54.096844 2016-11-08    None       None
# 336  55.072610 2017-02-21    None       None
# 337   0.000000 2017-07-04    None       None
# 338   0.000000 2017-07-04    None       None
# 339   0.000000        NaT    None  Collision
#
#                              Legislatio  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ..                                  ...
# 335                                None
# 336                                None
# 337                                None
# 338                                None
# 339  Protection Military Remains (1986)
#
#                                             Notes_1           Origin  \
# 0                                              None             None
# 1                                              None             None
# 2                                              None             None
# 3                                              None             None
# 4                                              None             None
# ..                                              ...              ...
# 335                                            None             None
# 336                                            None             None
# 337                                            None             None
# 338                                            None             None
# 339  Designated protected place. Position uncertain  Admiralty owned
#
#              Where_lost                   geometry
# 0                  None   POINT (-5.73822 54.8525)
# 1                  None  POINT (-5.62938 54.45155)
# 2                  None  POINT (-5.74132 54.94993)
# 3                  None   POINT (-5.6962 54.81548)
# 4                  None   POINT (-6.0985 54.05322)
# ..                  ...                        ...
# 335                None   POINT (-6.2084 54.09684)
# 336                None  POINT (-7.04008 55.07261)
# 337                None   POINT (-5.76075 55.0992)
# 338                None  POINT (-5.64846 55.02999)
# 339  60km N of Ireland?  POINT (-6.75512 55.70542)
#
# [340 rows x 24 columns]

# %% [markdown]
# Exploring this data, we see a range of ships - also a few data quality issues in the dates and missing values.
#
# If you have a look at the last, "geometry", column, you will see an entity in WKT (well-known text) format - a computer-readable way of specifying entities.

# %% [markdown]
# We can use matplotlib to take a look.

# %%
# %matplotlib inline

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## What? That's not a map

# %% [markdown]
# OK, so that's a scatterplot, which isn't much of a map. We have seen how Python allows us to easily combine different tools and modes of expression. We can use a package called `folium` to make OpenStreetMap / Google Maps style interactive maps.

# %%
import folium

# %% [markdown]
# Naturally, before we show a useful map, we need to decide how to centre it somewhere relevant.

# %% [markdown]
# As it happens, the point associated with each row in geopandas is a `Shapely` geometric entity. It could also be a line, polygon, circle, or a combination of those, for example. We can also ask for the `gdf.geometry`, which is the collection of all the row entities.
#
# Shapely is a geometric package - this means we can do geometric operations on the rows. For example, we can combine all the points into one polka-dot geometric entity - a union operation.

# %%
gdf.geometry.unary_union
# Out:
# /tmp/ipython-input-742342306.py:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   gdf.geometry.unary_union
# <MULTIPOINT ((-7.315 55.001), (-7.309 55.01), (-7.309 55.012), (-7.294 55.01...>

# %% [markdown]
# As a 2d geometric entity, it also has a centroid - a weighted midpoint - which will suffice for us to centre our map.

# %%
middle = gdf.geometry.unary_union.centroid
middle
# Out:
# /tmp/ipython-input-294470364.py:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   middle = gdf.geometry.unary_union.centroid
# <POINT (-5.825 54.644)>

# %% [markdown]
# Geometric manipulation is much more useful than mapping - it is critical in many forms of numerical analysis, engineering, design and 3d printing. Explore Shapely's toolkit at your leisure.

# %% [markdown]
# ## Map time

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
    ).add_to(fmap)
    return wreck

gdf = gdf.apply(add, axis=1)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9525f0885e74f865d9792f145c99fdcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9525f0885e74f865d9792f145c99fdcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9525f0885e74f865d9792f145c99fdcb = L.map(
#                 &quot;map_9525f0885e74f865d9792f145c99fdcb&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d524a6dd7848c943b15e98eece118df9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d524a6dd7848c943b15e98eece118df9.addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#             var marker_67cbb02efbb8e22955b13ea1d22f87e0 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {
# }
#             ).addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#         var popup_4c59a24883a3df4912490f5d54a00bce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe04bdd2471b06fe58b54c846f93faf3 = $(`&lt;div id=&quot;html_fe04bdd2471b06fe58b54c846f93faf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_4c59a24883a3df4912490f5d54a00bce.setContent(html_fe04bdd2471b06fe58b54c846f93faf3);
#
#
#
#         marker_67cbb02efbb8e22955b13ea1d22f87e0.bindPopup(popup_4c59a24883a3df4912490f5d54a00bce)
#         ;
#
#
#
#
#             var marker_60f0a308534e00b30a6e85098cfa1bc0 = L.marker(
#                 [54.45155042371992, -5.629383430791251],
#                 {
# }
#             ).addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#         var popup_83cefc2c674415cf3006484134f6f634 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a58c148945500f7f6dbf5f91c5ac90d = $(`&lt;div id=&quot;html_5a58c148945500f7f6dbf5f91c5ac90d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(ex HMS) Alastor&lt;/div&gt;`)[0];
#                 popup_83cefc2c674415cf3006484134f6f634.setContent(html_5a58c148945500f7f6dbf5f91c5ac90d);
#
#
#
#         marker_60f0a308534e00b30a6e85098cfa1bc0.bindPopup(popup_83cefc2c674415cf3006484134f6f634)
#         ;
#
#
#
#
#             var marker_e570ac6124e8b4027e28770203ccb230 = L.marker(
#                 [54.94993342278837, -5.741317099083887],
#                 {
# }
#             ).addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#         var popup_cd00404e249cba010ec65a8d5f9a996e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac85b0335d9d71cce22de9c9e70cc7b5 = $(`&lt;div id=&quot;html_ac85b0335d9d71cce22de9c9e70cc7b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albia (poss.)&lt;/div&gt;`)[0];
#                 popup_cd00404e249cba010ec65a8d5f9a996e.setContent(html_ac85b0335d9d71cce22de9c9e70cc7b5);
#
#
#
#         marker_e570ac6124e8b4027e28770203ccb230.bindPopup(popup_cd00404e249cba010ec65a8d5f9a996e)
#         ;
#
#
#
#
#             var marker_86b914a67ae1037e29494da1e5e6d1df = L.marker(
#                 [54.81548342367984, -5.696200098805885],
#                 {
# }
#             ).addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#         var popup_ba991ca6f827283799295d68b5067d90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae4d8a9ee0755b6a663000728d8d124f = $(`&lt;div id=&quot;html_ae4d8a9ee0755b6a663000728d8d124f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcedo&lt;/div&gt;`)[0];
#                 popup_ba991ca6f827283799295d68b5067d90.setContent(html_ae4d8a9ee0755b6a663000728d8d124f);
#
#
#
#         marker_86b914a67ae1037e29494da1e5e6d1df.bindPopup(popup_ba991ca6f827283799295d68b5067d90)
#         ;
#
#
#
#
#             var marker_0d89ee9e8a0e23aadbb71ccb130d13b0 = L.marker(
#                 [54.05321709066201, -6.098500100507256],
#                 {
# }
#             ).addTo(map_9525f0885e74f865d9792f145c99fdcb);
#
#
#         var popup_413f62beda911d3b2bfe33b5bf618c71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf127a492be7b7f2e13fd5f3dc708a89 = $(`&lt;div id=&quot;html_bf127a492be7b7f2e13fd5f3dc708a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alder&lt;/div&gt;`)[0];
#                 popup_413f62beda911d3b2bfe33b5bf618c71.setConte

# %% [markdown]
# That should be familiar - as previously, we use the `apply` method on a dataframe to iterate through it (a geopandas geodataframe, but it's essentially the same idea). In each step, we add a marker to the map.
#
# In the first line, we create a map, setting the centre and zoom. For each wreck, we add its coordinates to a new folium `Marker` and call the `add_to` method to append it to the map.

# %% [markdown]
# ## Exercise

# %% [markdown]
# Can you write a function that will take a string entry (it will be the content of the Date_Lost column) and return a string representing the century - '18', '19' or '20' - or None if it is not one of those?

# %% [markdown]
# CLUE: `dateutil` has a parser that can make a best guess at which date a string represents: `dateutil.parser.parse(dt)`

# %%
gdf.head()
# Out:
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ...   X_Coord    Y_Coord  \
# 0  UKHO, IRW, CMA   LIVE                None  ... -5.738217  54.852500
# 1  UKHO, IRW, CMA   LIVE                None  ... -5.629383  54.451550
# 2  IRW, UKHO, CMA   LIVE                None  ... -5.741317  54.949933
# 3        IRW, CMA   LIVE                None  ... -5.696200  54.815483
# 4            UKHO   LIFT  Wreck removed 1938  ... -6.098500  54.053217
#
#   Updated  Nation  How_lost  Legislatio Notes_1 Origin Where_lost  \
# 0     NaT    None      None        None    None   None       None
# 1     NaT    None      None        None    None   None       None
# 2     NaT    None      None        None    None   None       None
# 3     NaT    None      None        None    None   None       None
# 4     NaT    None      None        None    None   None       None
#
#                     geometry
# 0   POINT (-5.73822 54.8525)
# 1  POINT (-5.62938 54.45155)
# 2  POINT (-5.74132 54.94993)
# 3   POINT (-5.6962 54.81548)
# 4   POINT (-6.0985 54.05322)
#
# [5 rows x 24 columns]

# %%
import re

def get_century(date_str):
    # Find a 4-digit year in the string
    match = re.search(r"\b(\d{4})\b", date_str)
    if not match:
        return None  # No valid year found

    year = int(match.group(1))
    century = (year - 1) // 100 + 1
    return str(century)

# %%
r=get_century("01/01/1998")
r
# Out:
# '20'

# %% [markdown]
# Now we can add a `century` column to the data.

# %%
import pandas as pd

def add(wreck):
    try:
        wreck['century'] = get_century(wreck['Date_lost'])
    except Exception:
        wreck['century'] = pd.NA  # Pandas missing value
    return wreck

gdf = gdf.apply(add, axis=1)
gdf.head()
# Out:
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ...    Y_Coord Updated Nation  \
# 0  UKHO, IRW, CMA   LIVE                None  ...  54.852500     NaT   None
# 1  UKHO, IRW, CMA   LIVE                None  ...  54.451550     NaT   None
# 2  IRW, UKHO, CMA   LIVE                None  ...  54.949933     NaT   None
# 3        IRW, CMA   LIVE                None  ...  54.815483     NaT   None
# 4            UKHO   LIFT  Wreck removed 1938  ...  54.053217     NaT   None
#
#    How_lost  Legislatio  Notes_1 Origin Where_lost                   geometry  \
# 0      None        None     None   None       None   POINT (-5.73822 54.8525)
# 1      None        None     None   None       None  POINT (-5.62938 54.45155)
# 2      None        None     None   None       None  POINT (-5.74132 54.94993)
# 3      None        None     None   None       None   POINT (-5.6962 54.81548)
# 4      None        None     None   None       None   POINT (-6.0985 54.05322)
#
#   century
# 0      19
# 1      20
# 2      20
# 3      19
# 4    <NA>
#
# [5 rows x 25 columns]

# %% [markdown]
# Many points don't have a century, but lets ignore that for now.

# %% [markdown]
# Folium also lets us group markers. This is much more useful. Here we create several `FeatureGroup` map layers and them to the map. We then add markers directly to each century's FeatureGroup with coloured icons. At the end, we add a layer control, so you can turn each group on and off.

# %%
from folium import FeatureGroup, LayerControl

fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

centuries = {
    '18': 'red',
    '19': 'green',
    '20': 'blue'
}
clusters = {}

for century, colour in centuries.items():
    clusters[century] = FeatureGroup(name=century)
    clusters[century].add_to(fmap)

def add(wreck):
    try:
        wreck['century'] = get_century(wreck['Date_lost'])
    except Exception:
        wreck['century'] = None  # Use None for Folium

    pt = wreck.geometry
    if wreck['century'] in centuries:
        colour = centuries[wreck['century']]
        folium.Marker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            icon=folium.Icon(color=colour)
        ).add_to(clusters[wreck['century']])

    return wreck

gdf = gdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b9e11c32beae42692ef2b2af166c648 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b9e11c32beae42692ef2b2af166c648&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b9e11c32beae42692ef2b2af166c648 = L.map(
#                 &quot;map_1b9e11c32beae42692ef2b2af166c648&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_451a3300b8e2d863c559302cba58867b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_451a3300b8e2d863c559302cba58867b.addTo(map_1b9e11c32beae42692ef2b2af166c648);
#
#
#             var feature_group_bb424c2c7eb7976ecc1a4f51b0f0fa79 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_98ffa1ed0138b16be4a16b1982b04bfa = L.marker(
#                 [55.221667088797766, -6.592666773976079],
#                 {
# }
#             ).addTo(feature_group_bb424c2c7eb7976ecc1a4f51b0f0fa79);
#
#
#             var icon_8d1d5929b3b497c46f2ddde8ad60725d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a8e17638ef405b8b805b8a8ce053b8ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77a8aa7fbec289d4ed49ec648331675b = $(`&lt;div id=&quot;html_77a8aa7fbec289d4ed49ec648331675b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dei Sei&lt;/div&gt;`)[0];
#                 popup_a8e17638ef405b8b805b8a8ce053b8ac.setContent(html_77a8aa7fbec289d4ed49ec648331675b);
#
#
#
#         marker_98ffa1ed0138b16be4a16b1982b04bfa.bindPopup(popup_a8e17638ef405b8b805b8a8ce053b8ac)
#         ;
#
#
#
#
#                 marker_98ffa1ed0138b16be4a16b1982b04bfa.setIcon(icon_8d1d5929b3b497c46f2ddde8ad60725d);
#
#
#             var marker_f50cbb5ab22c4d5c75932c2c8d82c1ee = L.marker(
#                 [54.95220592595662, -5.74318382547431],
#                 {
# }
#             ).addTo(feature_group_bb424c2c7eb7976ecc1a4f51b0f0fa79);
#
#
#             var icon_8ba2ff4ae9eebebd9b53b9d026307553 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6f567c0d58016cdbb0f3af1ae1b6f35c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf343030e0df785dcddf8b11e8b2e7d0 = $(`&lt;div id=&quot;html_bf343030e0df785dcddf8b11e8b2e7d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Unknown&lt;/div&gt;`)[0];
#                 popup_6f567c0d58016cdbb0f3af1ae1b6f35c.setContent(html_bf343030e0df785dcddf8b11e8b2e7d0);
#
#
#
#         marker_f50cbb5ab22c4d5c75932c2c8d82c1ee.bindPopup(popup_6f567c0d58016cdbb0f3af1ae1b6f35c)
#         ;
#
#
#
#
#                 marker_f50cbb5ab22c4d5c75932c2c8d82c1ee.setIcon(icon_8ba2ff4ae9eebebd9b53b9d026307553);
#
#
#             var marker_753e018ff7b25107bb71a5a95405561c = L.marker(
#                 [54.27532456750983, -5.57018805270091],
#                 {
# }
#             ).addTo(feature_group_bb424c2c7eb7976ecc1a4f51b0f0fa79);
#
#
#             var icon_fec12f44858b9bded698de53cd5d1efb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ad6612baa0b98794d6ca9544523d212f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_716e325dd4f7be587b95c0ba4e29cdd0 = $(`&lt;div id=&quot;html_716e325dd4f7be587b95c0ba4e29cdd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L&#x27;Amite&lt;/div&gt;`)[0];
#                 popup_ad6612baa0b98794d6ca9544523d212f.setContent(html_716e325dd4f7be587b95c0ba4e29cdd0);
#
#
#
#         marker_753e018ff7b25107bb71a5a95405561c.bindPopup(popup_ad6612baa0b98794d6ca

# %% [markdown]
# ## Changing of the Seasons

# %% [markdown]
# Let's pick a century. 1900's, for example.

# %%
century = '19' # if you want to try a different century, come back here, change this and run the cells below

# %%
# kmeans isn't the best option, as lat-long is not linear and we are guessing cluster numbers,
# but this illustrates how it can work
from sklearn.cluster import KMeans
import numpy as np

gdf['label'] = -1
kdf = gdf[gdf['century'] == century]
locations = np.array([[w.geometry.y, w.geometry.x] for n, w in kdf.iterrows()])
locations
# Out:
# array([[54.85250042, -5.73821677],
#        [54.81548342, -5.6962001 ],
#        [54.44620042, -5.37560009],
#        [54.85368342, -5.7697831 ],
#        [54.78753342, -5.6885831 ],
#        [54.67150913, -5.77305105],
#        [55.27499802, -6.2025764 ],
#        [54.33125416, -5.49898497],
#        [54.06666709, -5.95833343],
#        [54.85222589, -5.7908119 ],
#        [55.29536126, -6.28592233],
#        [54.43380042, -5.39493309],
#        [55.26420184, -6.19813141],
#        [54.58333342, -5.4833331 ],
#        [55.27752641, -6.17896666],
#        [54.28088376, -5.52776676],
#        [55.28793222, -6.19234401],
#        [54.53983376, -5.45181565],
#        [54.95288342, -5.7302501 ],
#        [54.38882984, -5.56496278],
#        [55.19286713, -6.70915706],
#        [54.88200042, -5.75271677],
#        [55.17303376, -7.05555011],
#        [54.95286742, -5.7302501 ],
#        [54.69685785, -5.5302748 ],
#        [54.84621742, -5.7131001 ],
#        [55.14917541, -6.02282832],
#        [55.29163042, -6.2468801 ],
#        [55.20695042, -6.60878344],
#        [54.66873119, -5.52915254],
#        [54.68275689, -5.53408793],
#        [53.95381709, -5.92096677],
#        [55.16916709, -6.75961678],
#        [54.88255042, -5.75188343]])

# %% [markdown]
# Now we set up our k-means algorithm - this involves choosing an expected number of clusters - and fit it to our locations list. It generates a numpy array of labels, one entry for each location representing its cluster.

# %%
kmeans = KMeans(n_clusters=6).fit(locations)
kmeans.labels_
# Out:
# array([3, 3, 0, 3, 3, 3, 2, 5, 4, 3, 2, 0, 2, 0, 2, 5, 2, 0, 3, 5, 1, 3,
#        1, 3, 0, 3, 2, 2, 1, 0, 0, 4, 1, 3], dtype=int32)

# %% [markdown]
# We can then add these in the specific entries in the dataframe.

# %%
for n, label in enumerate(kmeans.labels_):
    gdf.loc[kdf.index[n], 'label'] = label

kdf = gdf[gdf['century'] == century]
kdf.loc[:, 'label'].head()
# Out:
# 0     3
# 3     3
# 10    0
# 18    3
# 22    3
# Name: label, dtype: int64

# %% [markdown]
# How does this look on the original map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

colours = ['red', 'green', 'blue', 'orange', 'pink', 'gray']
clusters = {}

for label, colour in enumerate(colours):
    clusters[label] = FeatureGroup(name="Cluster %d" % label)
    clusters[label].add_to(fmap)

def add(wreck):
    pt = wreck.geometry

    colour = colours[wreck['label']]
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
        icon=folium.Icon(color=colour)
    ).add_to(clusters[wreck['label']])

    return wreck

kdf = kdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fee2bb674cdb41aff90b105d7b518d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fee2bb674cdb41aff90b105d7b518d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fee2bb674cdb41aff90b105d7b518d2 = L.map(
#                 &quot;map_0fee2bb674cdb41aff90b105d7b518d2&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70472672ef6f8f6b4a9e730429ab479b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70472672ef6f8f6b4a9e730429ab479b.addTo(map_0fee2bb674cdb41aff90b105d7b518d2);
#
#
#             var feature_group_d9c4aa8d4262342cbf51b118d7007dbc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_188f2eb95259d167b101678a5841fc9e = L.marker(
#                 [54.44620042451414, -5.375600094540772],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_6476f3a9dcca1556689eaeef6c813f67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e29b85d7755afb723fef44f8ed898def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f45c4ba9da270fe13bc16ec79b7687c6 = $(`&lt;div id=&quot;html_f45c4ba9da270fe13bc16ec79b7687c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_e29b85d7755afb723fef44f8ed898def.setContent(html_f45c4ba9da270fe13bc16ec79b7687c6);
#
#
#
#         marker_188f2eb95259d167b101678a5841fc9e.bindPopup(popup_e29b85d7755afb723fef44f8ed898def)
#         ;
#
#
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#             var marker_fd90177192ee50fe773e2e25016b52d2 = L.marker(
#                 [54.433800424660134, -5.394933094997671],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_23160f882021a78b2d7a3b4d8460d1fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3c3ba4847e1942036c7df24047534cb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_652b81281689251e93ceffb1c8508c3e = $(`&lt;div id=&quot;html_652b81281689251e93ceffb1c8508c3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harold&lt;/div&gt;`)[0];
#                 popup_3c3ba4847e1942036c7df24047534cb8.setContent(html_652b81281689251e93ceffb1c8508c3e);
#
#
#
#         marker_fd90177192ee50fe773e2e25016b52d2.bindPopup(popup_3c3ba4847e1942036c7df24047534cb8)
#         ;
#
#
#
#
#                 marker_fd90177192ee50fe773e2e25016b52d2.setIcon(icon_23160f882021a78b2d7a3b4d8460d1fb);
#
#
#             var marker_e4002a297c364571afc80a7f582f82a2 = L.marker(
#                 [54.58333342410078, -5.483333096075104],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_df8f902eb99487e7ed1b0735d690d7a4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_747b6cc4c87077b8099e06cd88a4cae3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae6095b5579c6bc3ac50b603a2f32f24 = $(`&lt;div id=&quot;html_ae6095b5579c6bc3ac50b603a2f32f24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Inverurie&lt;/div&gt;`)[0];
#                 popup_747b6cc4c87077b8099e06cd88a4cae3.setContent(html_ae6095b5579c6bc3ac50b603a2f32f24);
#
#
#
#         marker_e4002a297c364571afc80a7f582f82a2.bindPopup(popup_747b6cc4c8707

# %% [markdown]
# # Quiz
#
# * Which of NI's main harbours match to which clusters?
# * How does it change with the number of labels you use?
# * How does it change with the century?

# %% [markdown]
# **Ans1:** Red cluster(0) falls near Causeway and Antrim Cost
#
# **Ans2:** Increasing or decreasing the number of clusters (n_clusters in the KMeans algorithm) will change how the wrecks are grouped. A higher number of clusters will result in smaller, more localized groups, while a lower number will create larger, broader groups.
#
# **Ans3:** The distribution of shipwrecks can vary significantly across different centuries due to changes in shipping routes, technology, and historical events. Running the clustering for other centuries (18th and 20th) would likely reveal different spatial patterns and potentially different areas of concentration.

# %% [markdown]
# # Looks deep

# %% [markdown]
# Next question: is there a correlation between depth and number of shipwrecks?
#
# Rather than using the official bathymetry data, we will try and guess depth from shades of blue in satellite images. There's a few issues with our approach here - such as the resolution of the images, the processing that's already been done to them, the fact that colour isn't necessarily a good proxy for depth - but it will demonstrate how we can use image manipulation to back up other analysis.

# %% [markdown]
# First, we show the Sentinel-2 open satellite data as a map layer.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

attr = """
<i>
<a class="a-light" xmlns:dct="http://purl.org/dc/terms/"
      href="https://s2maps.eu" property="dct:title">
  Sentinel-2 cloudless - https://s2maps.eu
</a> by
<a class="a-light" xmlns:cc="http://creativecommons.org/ns#"
      href="https://eox.at" property="cc:attributionName"
      rel="cc:attributionURL">
  EOX IT Services GmbH
</a><br/>
(Contains modified Copernicus Sentinel data 2016 &amp; 2017)</i>
"""
sentinel = folium.WmsTileLayer(
    url='https://tiles.maps.eox.at/wms',
    name='s2maps.eu',
    fmt='image/png',
    attr=attr,
    layers='s2cloudless_3857'
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18ea46c4685f5a4df1aa10b9f34e735e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18ea46c4685f5a4df1aa10b9f34e735e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18ea46c4685f5a4df1aa10b9f34e735e = L.map(
#                 &quot;map_18ea46c4685f5a4df1aa10b9f34e735e&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c085350db59f7dd1aff0b748f6efb0b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c085350db59f7dd1aff0b748f6efb0b.addTo(map_18ea46c4685f5a4df1aa10b9f34e735e);
#
#
#             var macro_element_f37f76b692b86237245a03c0b4261489 = L.tileLayer.wms(
#                 &quot;https://tiles.maps.eox.at/wms&quot;,
#                 {&quot;attribution&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;s2cloudless_3857&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: false, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_f37f76b692b86237245a03c0b4261489.addTo(map_18ea46c4685f5a4df1aa10b9f34e735e);
#
#
#             var feature_group_d9c4aa8d4262342cbf51b118d7007dbc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_188f2eb95259d167b101678a5841fc9e = L.marker(
#                 [54.44620042451414, -5.375600094540772],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_6476f3a9dcca1556689eaeef6c813f67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e29b85d7755afb723fef44f8ed898def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f45c4ba9da270fe13bc16ec79b7687c6 = $(`&lt;div id=&quot;html_f45c4ba9da270fe13bc16ec79b7687c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_e29b85d7755afb723fef44f8ed898def.setContent(html_f45c4ba9da270fe13bc16ec79b7687c6);
#
#
#
#         marker_188f2eb95259d167b101678a5841fc9e.bindPopup(popup_e29b85d7755afb723fef44f8ed898def)
#         ;
#
#
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#             var marker_fd90177192ee50fe773e2e25016b52d2 = L.marker(
#                 [54.433800424660134, -5.394933094997671],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_23160f882021a78b2d7a3b4d8460d1fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3c3ba4847e1942036c7df24047534cb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_652b81281689251e93ceffb1c8508c3e = $(`&lt;div id=&quot;html_652b81281689251e93ceffb1c8508c3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Harold&lt;/div&gt;`)[0];
#                 popup_3c3ba4847e1942036c7df24047534cb8.setContent(html_652b81281689251e93ceffb1c8508c3e);
#
#
#
#         marker_fd90177192ee50fe773e2e25016b52d2.bindPopup(popup_3c3ba4847e1942036c7df24047534cb8)

# %% [markdown]
# Rather than examining _all_ this data - I have chopped out a tile for our convenience. An image we can manipulate...

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

tile = folium.raster_layers.ImageOverlay(
    url='https://tiles.maps.eox.at/wms',
    name='coast',
    image='/content/coast.jpg',
    fmt='jpg',
    bounds=[[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]],
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f902d06fd2b214e9c4352966c1eb41a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f902d06fd2b214e9c4352966c1eb41a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f902d06fd2b214e9c4352966c1eb41a = L.map(
#                 &quot;map_0f902d06fd2b214e9c4352966c1eb41a&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f89bda45d64af6ab5b2152218b56aec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f89bda45d64af6ab5b2152218b56aec.addTo(map_0f902d06fd2b214e9c4352966c1eb41a);
#
#
#             var image_overlay_6d7f89e1e0f6563f2af57b5ade926772 = L.imageOverlay(
#                 &quot;data:image/jpg;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {
#   &quot;url&quot;: &quot;https://tiles.maps.eox.at/wms&quot;,
#   &quot;fmt&quot;: &quot;jpg&quot;,
#   &quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;,
#   &quot;opacity&quot;: 0.6,
#   &quot;zindex&quot;: 1,
# }
#             );
#
#
#             image_overlay_6d7f89e1e0f6563f2af57b5ade926772.addTo(map_0f902d06fd2b214e9c4352966c1eb41a);
#
#
#             var feature_group_d9c4aa8d4262342cbf51b118d7007dbc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_188f2eb95259d167b101678a5841fc9e = L.marker(
#                 [54.44620042451414, -5.375600094540772],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_6476f3a9dcca1556689eaeef6c813f67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e29b85d7755afb723fef44f8ed898def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f45c4ba9da270fe13bc16ec79b7687c6 = $(`&lt;div id=&quot;html_f45c4ba9da270fe13bc16ec79b7687c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_e29b85d7755afb723fef44f8ed898def.setContent(html_f45c4ba9da270fe13bc16ec79b7687c6);
#
#
#
#         marker_188f2eb95259d167b101678a5841fc9e.bindPopup(popup_e29b85d7755afb723fef44f8ed898def)
#         ;
#
#
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#             var marker_fd90177192ee50fe773e2e25016b52d2 = L.marker(
#                 [54.433800424660134, -5.394933094997671],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_23160f882021a78b2d7a3b4d8460d1fb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &q

# %% [markdown]
# Now, how do we actually use a picture like data? scikit-image (skimage) has a lot of image manipulation tools - these can be coupled with scikit-learn in certain contexts to do image-based machine learning, so this is a brief intro.

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
# %matplotlib inline

# %%
coast = skimage.io.imread('/content/coast.jpg')
plt.imshow(coast)

# %% [markdown]
# We have actually imported this image as a numpy array. In fact, this is actually plotting using the same technique as our Inflammation numpy tutorial - it's a graph of cells, where each cell has colour values. Pixels you might say...

# %%
coast[0, 0, :]
# Out:
# array([14, 33, 48], dtype=uint8)

# %% [markdown]
# First, we soften some of the noise using a Gaussian blur.

# %%
from skimage import filters

smooth = filters.gaussian(coast, sigma=10)
plt.imshow(smooth)

# %% [markdown]
# As this is a 3d matrix, as far as numpy is concerned, we can extract a single colour channel using a slice. Here is the green one (think RGB - G has index 1).

# %%
plt.imshow(smooth[:,:,1])

# %% [markdown]
# A simple, coarse way to trim all the non-sea (land, as it's known) is to pick everything that is more than a little green. Here we set anything with more than 0.2 in the green column to black.

# %%
smooth[smooth[:,:,1] > 0.2] = [0, 0, 0]
plt.imshow(smooth)

# %% [markdown]
# Next, we go one step further, by selecting _just_ the blue channel and trimming (setting to -1) everything that is outside of an emperical or heuristic (i.e. guessed or made up) window.

# %%
sea = smooth[:,:,2].copy()
sea[(sea < 0.1) | (sea > 0.25)] =-1
plt.imshow(sea)

# %% [markdown]
# OK, so we have some sea now - we know where it is. Now lets split it into layers of deep and shallow. To do this, we use a basic image segmentation technique, which is no more than numpy's `histogram` function. This puts all of our pixels into labeled "bins" (or layers, in our 2d image case).

# %%
# This number is our own choice of sea-depth layers
bins = 5

# We split up the sea into a set of bins
hist, bin_edges = np.histogram(
    sea,
    bins=bins,
    range=(sea[sea > 0].min(), sea.max())
)

# And create a new array called layers that matches each pixel to a depth layer: shallow...deep
last_edge = bin_edges[0]
layers = np.zeros(sea.shape, dtype=int) - 1
for n, next_edge in enumerate(bin_edges[1:]):
    layers[(sea > last_edge) & (sea <= next_edge)] = n
    last_edge = next_edge
plt.imshow(layers)

# %% [markdown]
# Now we can see the variety of layers - with as many colours as our `bins` variable.

# %% [markdown]
# As an aside for later - let's calculate what fraction of the visible sea each layer takes up.

# %%
segment_frequencies = np.bincount(layers[layers >= 0].flatten())
nonzero_pixels = sum(segment_frequencies)
segment_fraction = segment_frequencies / nonzero_pixels
segment_fraction
# Out:
# array([0.20094781, 0.32737723, 0.14417245, 0.11758879, 0.20991372])

# %% [markdown]
# ## Back to charts
#
# Does this match up with our map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

layer_bounds = [[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]]

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fc16a2dac65f8d12050b169e00ef682 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fc16a2dac65f8d12050b169e00ef682&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fc16a2dac65f8d12050b169e00ef682 = L.map(
#                 &quot;map_1fc16a2dac65f8d12050b169e00ef682&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2dd9b2e670112e8be09460cec615793 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2dd9b2e670112e8be09460cec615793.addTo(map_1fc16a2dac65f8d12050b169e00ef682);
#
#
#             var image_overlay_7ce75fabf99a622caef6519024d05b12 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {
#   &quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;,
#   &quot;opacity&quot;: 0.6,
#   &quot;zindex&quot;: 1,
# }
#             );
#
#
#             image_overlay_7ce75fabf99a622caef6519024d05b12.addTo(map_1fc16a2dac65f8d12050b169e00ef682);
#
#
#             var feature_group_d9c4aa8d4262342cbf51b118d7007dbc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_188f2eb95259d167b101678a5841fc9e = L.marker(
#                 [54.44620042451414, -5.375600094540772],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_6476f3a9dcca1556689eaeef6c813f67 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e29b85d7755afb723fef44f8ed898def = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f45c4ba9da270fe13bc16ec79b7687c6 = $(`&lt;div id=&quot;html_f45c4ba9da270fe13bc16ec79b7687c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_e29b85d7755afb723fef44f8ed898def.setContent(html_f45c4ba9da270fe13bc16ec79b7687c6);
#
#
#
#         marker_188f2eb95259d167b101678a5841fc9e.bindPopup(popup_e29b85d7755afb723fef44f8ed898def)
#         ;
#
#
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#                 marker_188f2eb95259d167b101678a5841fc9e.setIcon(icon_6476f3a9dcca1556689eaeef6c813f67);
#
#
#             var marker_fd90177192ee50fe773e2e25016b52d2 = L.marker(
#                 [54.433800424660134, -5.394933094997671],
#                 {
# }
#             ).addTo(feature_group_d9c4aa8d4262342cbf51b118d7007dbc);
#
#
#             var icon_23160f882021a78b2d7a3b4d8460d1fb = L.AwesomeMarkers.icon(
#                 {
#   &qu

# %% [markdown]
# Close enough, given all the approximations. Next...
#
# ## Labelling our wrecks
#
# We need to create a function that we can pass a wreck to, and it will give its corresponding layer.
#
# We have a couple of convenient tools in scipy and numpy:
# * linspace : this creates an array linearly spread from one limit to another
# * meshgrid : this turns a set of horizontal and vertical axis ticks into a list of all the points in the corresponding grid
# * inter2p : this takes a series of axis ticks and function values at every grid point, and gives a callable function taking any coordinate whatsoever and returning the linearly-interpolated function value

# %%
import scipy
from scipy.interpolate import RegularGridInterpolator

layer_x = np.linspace(layer_bounds[0][1], layer_bounds[1][1], len(layers[0]))
layer_y = np.linspace(layer_bounds[1][0], layer_bounds[0][0], len(layers))

# Create the interpolator
segment_interp = RegularGridInterpolator((layer_y, layer_x), layers)

# %% [markdown]
# We can plot this interpolated function to see what it looks like in 3D.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(projection='3d')
ax.set_zlim(-10, 10)
ax.view_init(60, -90)

X, Y = np.meshgrid(layer_x, layer_y)
surf = ax.plot_surface(X, Y, segment_interp((Y, X)), cmap=cm.coolwarm)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# Finally, to use our interpolated labelling function, we turn back to our old dataframe method, `apply`.

# %%
def point_to_segment(wreck):
    try:
        interp = segment_interp((wreck.geometry.y, wreck.geometry.x))
        wreck['segment'] = int(round(interp.item()))
    except ValueError:
        wreck['segment'] = -1  # Assign -1 for out-of-bounds points
    return wreck
gdf = gdf.apply(point_to_segment, axis=1)
gdf.head()
# Out:
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ... Nation How_lost Legislatio  \
# 0  UKHO, IRW, CMA   LIVE                None  ...   None     None       None
# 1  UKHO, IRW, CMA   LIVE                None  ...   None     None       None
# 2  IRW, UKHO, CMA   LIVE                None  ...   None     None       None
# 3        IRW, CMA   LIVE                None  ...   None     None       None
# 4            UKHO   LIFT  Wreck removed 1938  ...   None     None       None
#
#    Notes_1  Origin  Where_lost                   geometry century label  \
# 0     None    None        None   POINT (-5.73822 54.8525)      19     3
# 1     None    None        None  POINT (-5.62938 54.45155)      20    -1
# 2     None    None        None  POINT (-5.74132 54.94993)      20    -1
# 3     None    None        None   POINT (-5.6962 54.81548)      19     3
# 4     None    None        None   POINT (-6.0985 54.05322)    None    -1
#
#   segment
# 0       2
# 1       2
# 2       1
# 3       2
# 4      -1
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Displaying this detail

# %% [markdown]
# Lets work out which segments we actually have wrecks in (we don't want to add more layers than necessary)

# %%
segments_active = set(gdf.loc[:, 'segment']) - {-1}
segments_active
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# Now lets create a copy of our dataframe for further manipulation.

# %%
# ldf = gdf.copy()
ldf = gdf[gdf['century'] == '19'].copy()

# %% [markdown]
# Much as above, we can run through our wrecks, but we use a handy colourmap library to give us shades indicating our depth layer.

# %%
import branca.colormap as cm

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

mid = min(segments_active) + (max(segments_active) - min(segments_active)) / 2
colormap = cm.LinearColormap(
    ['red', 'yellow', 'green'],
    index=[min(segments_active), mid, max(segments_active)]
)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            fill_color=colour,
            color=colour
        ).add_to(fmap)

    return wreck

ldf = ldf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0ee817f291120cec77824f908e8e1c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0ee817f291120cec77824f908e8e1c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0ee817f291120cec77824f908e8e1c4 = L.map(
#                 &quot;map_e0ee817f291120cec77824f908e8e1c4&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffc61356f2a48152b7b65b99c0621d36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffc61356f2a48152b7b65b99c0621d36.addTo(map_e0ee817f291120cec77824f908e8e1c4);
#
#
#             var circle_marker_c2bbe08c7d2641264ff31b9a4930b175 = L.circleMarker(
#                 [54.852500423720116, -5.738216765202008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e0ee817f291120cec77824f908e8e1c4);
#
#
#         var popup_a996df6a2ded0f86e357e87567e47929 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90946fa0e9903d32979c6a979e687cb1 = $(`&lt;div id=&quot;html_90946fa0e9903d32979c6a979e687cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_a996df6a2ded0f86e357e87567e47929.setContent(html_90946fa0e9903d32979c6a979e687cb1);
#
#
#
#         circle_marker_c2bbe08c7d2641264ff31b9a4930b175.bindPopup(popup_a996df6a2ded0f86e357e87567e47929)
#         ;
#
#
#
#
#             var circle_marker_7a909282ce79d442b5d41692303d5f26 = L.circleMarker(
#                 [54.81548342367984, -5.696200098805885],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e0ee817f291120cec77824f908e8e1c4);
#
#
#         var popup_742b20214a9e768e6368af1f38220fd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce41391e18d4452ba516c67ad1bc4bfd = $(`&lt;div id=&quot;html_ce41391e18d4452ba516c67ad1bc4bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcedo&lt;/div&gt;`)[0];
#                 popup_742b20214a9e768e6368af1f38220fd6.setContent(html_ce41391e18d4452ba516c67ad1bc4bfd);
#
#
#
#         circle_marker_7a909282ce79d442b5d41692303d5f26.bindPopup(popup_742b20214a9e768e6368af1f38220fd6)
#         ;
#
#
#
#
#             var circle_marker_9abe5d6f25dff9437277cbcb5a8c8589 = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e0ee817f291120cec77824f908e8e1c4);
#
#
#         var popup_3bbb580178167b56c2a82bbb1444e2ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d26cf438d334c9a93f3c2b775e8aa6ce = $(`&lt;div id=&quot;html_d26cf438d334c9a93f3c2b775e8aa6ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_3bbb580178167b56c2a82bbb1444e2ff.setContent(html_d26cf438d334c9a93f3c2b775e8aa6ce);
#
#
#
#         circle_marker_9abe5d6f25dff9437277cbcb5a8c8589.bindPopup(popup_3bbb580178167b56c2a82bbb1444e2ff)
#         ;

# %% [markdown]
# So that's nice, but it still doesn't answer our question - is there a correlation between depth and wreck frequency? Time to do some stats...

# %%
segment_table = ldf[ldf['segment'] > -1].groupby('segment').agg('count')

total_segmented = segment_table['Name'].sum()

def percentage(row):
    row['Count'] = row['Name']
    row['Blue Depth'] = bin_edges[row.name]
    row['% wrecks'] = 100 * row['Name'] / total_segmented
    row['% area'] = 100 * segment_fraction[row.name]
    row['Wreck Frequency'] = row['% wrecks'] / row['% area']
    return row

segment_table = segment_table.apply(percentage, axis=1)
segment_table = segment_table[['Count', 'Blue Depth', '% wrecks', '% area', 'Wreck Frequency']]
segment_table
# Out:
#          Count  Blue Depth  % wrecks     % area  Wreck Frequency
# segment
# 0          1.0    0.100006     3.125  20.094781         0.155513
# 1          7.0    0.121379    21.875  32.737723         0.668189
# 2         14.0    0.142752    43.750  14.417245         3.034560
# 3          7.0    0.164126    21.875  11.758879         1.860296
# 4          3.0    0.185499     9.375  20.991372         0.446612

# %% [markdown]
# So not hugely, but around a third higher for the shallow (mostly coastal) areas. Not a huge gap, but oh well... it may be worth trying for other centuries though...

# %% [markdown]
# In any case, let's put it all together and see what our shipwreck map now looks like.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup="%s (%.2lf, %.2lf)" % (wreck['Name'], wreck.geometry.y, wreck.geometry.x),
            fill_color=colour,
            fill_opacity=1,
            radius=8,
            color=colour
        ).add_to(fmap)

    return wreck

ldf.apply(add, axis=1)

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.9,
    zindex=1
).add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d1cf7e4a65b8e4a56971d30c1402b33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d1cf7e4a65b8e4a56971d30c1402b33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d1cf7e4a65b8e4a56971d30c1402b33 = L.map(
#                 &quot;map_0d1cf7e4a65b8e4a56971d30c1402b33&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f29f7379e22ca5bf66a4019cf053073 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f29f7379e22ca5bf66a4019cf053073.addTo(map_0d1cf7e4a65b8e4a56971d30c1402b33);
#
#
#             var circle_marker_bf16f5424b0e73959872ddf6f47696f1 = L.circleMarker(
#                 [54.852500423720116, -5.738216765202008],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d1cf7e4a65b8e4a56971d30c1402b33);
#
#
#         var popup_f16e3712e88ee03e127251ffdb2d2baf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6e605c98071a50f00f52000638cc1f = $(`&lt;div id=&quot;html_ac6e605c98071a50f00f52000638cc1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa (54.85, -5.74)&lt;/div&gt;`)[0];
#                 popup_f16e3712e88ee03e127251ffdb2d2baf.setContent(html_ac6e605c98071a50f00f52000638cc1f);
#
#
#
#         circle_marker_bf16f5424b0e73959872ddf6f47696f1.bindPopup(popup_f16e3712e88ee03e127251ffdb2d2baf)
#         ;
#
#
#
#
#             var circle_marker_e38af5a8b1ed22efa2499d84b752b1c5 = L.circleMarker(
#                 [54.81548342367984, -5.696200098805885],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0d1cf7e4a65b8e4a56971d30c1402b33);
#
#
#         var popup_d14351ca534b7b9257593d26f362a0e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25eaad8f4fc93e54746842a4fee48345 = $(`&lt;div id=&quot;html_25eaad8f4fc93e54746842a4fee48345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcedo (54.82, -5.70)&lt;/div&gt;`)[0];
#                 popup_d14351ca534b7b9257593d26f362a0e9.setContent(html_25eaad8f4fc93e54746842a4fee48345);
#
#
#
#         circle_marker_e38af5a8b1ed22efa2499d84b752b1c5.bindPopup(popup_d14351ca534b7b9257593d26f362a0e9)
#         ;
#
#
#
#
#             var circle_marker_928d89f0ca3ea3f9220fbc3b6be3c8cf = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).ad

# %% [markdown]
# # Exercise

# %% [markdown]
# Try rerunning the above for different centuries. Do all centuries (with data) have similar results? Does this tell you something about seafaring over time? Are all century datasets equally valid for analysis?

# %% [markdown]
# # Answers

# %%
# Step 1: Select a century
century = '18'
# Step 2: Perform clustering
# kmeans isn't the best option, as lat-long is not linear and we are guessing cluster numbers,
# but this illustrates how it can work
from sklearn.cluster import KMeans
import numpy as np

# Filter data for the selected century and drop rows with missing geometry or Date_lost
kdf = gdf[(gdf['century'] == century) & (gdf['geometry'].notna()) & (gdf['Date_lost'].notna())].copy()

if not kdf.empty:
    locations = np.array([[w.geometry.y, w.geometry.x] for n, w in kdf.iterrows()])

    # Determine the number of clusters. You might want to experiment with this number.
    n_clusters = min(len(locations), 6) # Use at most 6 clusters, or fewer if there are fewer wrecks

    if n_clusters > 0:
        kmeans = KMeans(n_clusters=n_clusters, random_state=0, n_init=10).fit(locations) # Added random_state and n_init for reproducibility
        kdf.loc[:, 'label'] = kmeans.labels_

        # Step 3: Visualize the clusters
        fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

        colours = ['red', 'green', 'blue', 'orange', 'pink', 'gray'][:n_clusters] # Use only enough colors as there are clusters
        clusters = {}

        for label, colour in enumerate(colours):
            clusters[label] = FeatureGroup(name="Cluster %d" % label)
            clusters[label].add_to(fmap)

        def add_clustered_wreck(wreck):
            pt = wreck.geometry

            if wreck['label'] in clusters: # Ensure the label exists in the clusters dictionary
                colour = colours[wreck['label']]
                folium.Marker(
                    [pt.y, pt.x],
                    popup=wreck['Name'],
                    icon=folium.Icon(color=colour)
                ).add_to(clusters[wreck['label']])

            return wreck

        kdf.apply(add_clustered_wreck, axis=1)

        LayerControl().add_to(fmap)
        display(fmap) # Use display() to show the map in Colab
    else:
        print(f"Not enough data points to form clusters for the {century}th century.")
else:
    print(f"No data available for the {century}th century with valid geometry and Date_lost.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_094d595c8212cb0b5d678b5d7da89fdb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_094d595c8212cb0b5d678b5d7da89fdb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_094d595c8212cb0b5d678b5d7da89fdb = L.map(
#                 &quot;map_094d595c8212cb0b5d678b5d7da89fdb&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af0d5f4a3e3c81a63b93c2c6e754106e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af0d5f4a3e3c81a63b93c2c6e754106e.addTo(map_094d595c8212cb0b5d678b5d7da89fdb);
#
#
#             var feature_group_bd010da2135136ad9925142f51bbad7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_976b5b728f274d5f5a0a555dbcaa9a68 = L.marker(
#                 [54.27532456750983, -5.57018805270091],
#                 {
# }
#             ).addTo(feature_group_bd010da2135136ad9925142f51bbad7b);
#
#
#             var icon_b3087afd0524f2be3b99c81782b7d2d8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0f971b671f67d1b9f68569228ed8e78c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c26b94ab62450cd351c384a802cbe686 = $(`&lt;div id=&quot;html_c26b94ab62450cd351c384a802cbe686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;L&#x27;Amite&lt;/div&gt;`)[0];
#                 popup_0f971b671f67d1b9f68569228ed8e78c.setContent(html_c26b94ab62450cd351c384a802cbe686);
#
#
#
#         marker_976b5b728f274d5f5a0a555dbcaa9a68.bindPopup(popup_0f971b671f67d1b9f68569228ed8e78c)
#         ;
#
#
#
#
#                 marker_976b5b728f274d5f5a0a555dbcaa9a68.setIcon(icon_b3087afd0524f2be3b99c81782b7d2d8);
#
#
#             feature_group_bd010da2135136ad9925142f51bbad7b.addTo(map_094d595c8212cb0b5d678b5d7da89fdb);
#
#
#             var feature_group_9e0bc048da043a8f9b3e2040014099d7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bf5d2c570d4cc0432a6ea95a9d16c43c = L.marker(
#                 [55.22225365268374, -6.629235293324471],
#                 {
# }
#             ).addTo(feature_group_9e0bc048da043a8f9b3e2040014099d7);
#
#
#             var icon_9ac7fdeb9cf08e61e7e95af444776ee9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6423fa5fc17320763076c93ab71cab7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_049288e579ae049645a82dc575c0532c = $(`&lt;div id=&quot;html_049288e579ae049645a82dc575c0532c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N/A&lt;/div&gt;`)[0];
#                 popup_6423fa5fc17320763076c93ab71cab7e.setContent(html_049288e579ae049645a82dc575c0532c);
#
#
#
#         marker_bf5d2c570d4cc0432a6ea95a9d16c43c.bindPopup(popup_6423fa5fc17320763076c93ab71cab7e)
#         ;
#
#
#
#
#                 marker_bf5d2c570d4cc0432a6ea95a9d16c43c.setIcon(icon_9ac7fdeb9cf08e61e7e95af444776ee9);
#
#
#             feature_group_9e0bc048da043a8f9b3e2040014099d7.addTo(map_094d595c8212cb0b5d678b5d7da89fdb);
#
#
#             var feature_group_df252589f54776ea7f8b215fe5e8ad61 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d352a04224dcda25e91552e7f7899991 = L.marker(
#                 [54.95220592595662, -5.74318382547431],
#                 {
# }
#             ).addTo(feature_group_df252589f54776ea7f8b215fe5e8ad61);
#
#
#             var icon_a85d7f799306d7f55f6d879530666cc7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2cf34b0aa81399d30bd9e9835d0fbc05 =

# %%
# Step 1: Select a century
century = '20'

# Step 2: Perform clustering
# kmeans isn't the best option, as lat-long is not linear and we are guessing cluster numbers,
# but this illustrates how it can work
from sklearn.cluster import KMeans
import numpy as np

# Filter data for the selected century and drop rows with missing geometry or Date_lost
kdf = gdf[(gdf['century'] == century) & (gdf['geometry'].notna()) & (gdf['Date_lost'].notna())].copy()

if not kdf.empty:
    locations = np.array([[w.geometry.y, w.geometry.x] for n, w in kdf.iterrows()])

    # Determine the number of clusters. You might want to experiment with this number.
    n_clusters = min(len(locations), 6) # Use at most 6 clusters, or fewer if there are fewer wrecks

    if n_clusters > 0:
        kmeans = KMeans(n_clusters=n_clusters, random_state=0, n_init=10).fit(locations) # Added random_state and n_init for reproducibility
        kdf.loc[:, 'label'] = kmeans.labels_

        # Step 3: Visualize the clusters
        fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

        colours = ['red', 'green', 'blue', 'orange', 'pink', 'gray'][:n_clusters] # Use only enough colors as there are clusters
        clusters = {}

        for label, colour in enumerate(colours):
            clusters[label] = FeatureGroup(name="Cluster %d" % label)
            clusters[label].add_to(fmap)

        def add_clustered_wreck(wreck):
            pt = wreck.geometry

            if wreck['label'] in clusters: # Ensure the label exists in the clusters dictionary
                colour = colours[wreck['label']]
                folium.Marker(
                    [pt.y, pt.x],
                    popup=wreck['Name'],
                    icon=folium.Icon(color=colour)
                ).add_to(clusters[wreck['label']])

            return wreck

        kdf.apply(add_clustered_wreck, axis=1)

        LayerControl().add_to(fmap)
        display(fmap) # Use display() to show the map in Colab
    else:
        print(f"Not enough data points to form clusters for the {century}th century.")
else:
    print(f"No data available for the {century}th century with valid geometry and Date_lost.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb36ed9e588283b2c14136f555ae669e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb36ed9e588283b2c14136f555ae669e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb36ed9e588283b2c14136f555ae669e = L.map(
#                 &quot;map_cb36ed9e588283b2c14136f555ae669e&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a043e1973c33abb33bda2a478071491 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a043e1973c33abb33bda2a478071491.addTo(map_cb36ed9e588283b2c14136f555ae669e);
#
#
#             var feature_group_d424969e5717f165412ad8a35d03807d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5bf0b888bd3732de5f717eb9592656e9 = L.marker(
#                 [54.45155042371992, -5.629383430791251],
#                 {
# }
#             ).addTo(feature_group_d424969e5717f165412ad8a35d03807d);
#
#
#             var icon_654cbf7e969f96891ed3c87ed037f70a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_ac87249916b55f63e1081535639996d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b69c07c6ca5efa15b3fb9badeb4aa38 = $(`&lt;div id=&quot;html_7b69c07c6ca5efa15b3fb9badeb4aa38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(ex HMS) Alastor&lt;/div&gt;`)[0];
#                 popup_ac87249916b55f63e1081535639996d4.setContent(html_7b69c07c6ca5efa15b3fb9badeb4aa38);
#
#
#
#         marker_5bf0b888bd3732de5f717eb9592656e9.bindPopup(popup_ac87249916b55f63e1081535639996d4)
#         ;
#
#
#
#
#                 marker_5bf0b888bd3732de5f717eb9592656e9.setIcon(icon_654cbf7e969f96891ed3c87ed037f70a);
#
#
#             var marker_d9109357e58c69289d977469aef67fdb = L.marker(
#                 [54.47433375774758, -5.38633342867518],
#                 {
# }
#             ).addTo(feature_group_d424969e5717f165412ad8a35d03807d);
#
#
#             var icon_33a880b56bb4dd2abb622cc45f308679 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b03c360671a23ff73a7b7aeda850e90f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35743911434870d7d0b64a18ce2fa0c = $(`&lt;div id=&quot;html_a35743911434870d7d0b64a18ce2fa0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amber&lt;/div&gt;`)[0];
#                 popup_b03c360671a23ff73a7b7aeda850e90f.setContent(html_a35743911434870d7d0b64a18ce2fa0c);
#
#
#
#         marker_d9109357e58c69289d977469aef67fdb.bindPopup(popup_b03c360671a23ff73a7b7aeda850e90f)
#         ;
#
#
#
#
#                 marker_d9109357e58c69289d977469aef67fdb.setIcon(icon_33a880b56bb4dd2abb622cc45f308679);
#
#
#             var marker_2cf1056733fde15f3a8cc349880071f8 = L.marker(
#                 [54.37433375806866, -5.441616761483558],
#                 {
# }
#             ).addTo(feature_group_d424969e5717f165412ad8a35d03807d);
#
#
#             var icon_96b8a3751269536cf7a8c25ff85255b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_caee32602d23b5a70911ef7e4a1bb1ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e25cf37dc986e2fea4bc2ffd10aa6f5 = $(`&lt;div id=&quot;html_3e25cf37dc986e2fea4bc2ffd10aa6f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arantzazu Mendi&lt;/div&gt;`)[0];
#                 popup_caee32602d23b5a70911ef7e4a1bb1ed.setContent(html_3e25cf37dc986e2fea4bc2ffd10aa6f5);
#
#
#
#         marker_2cf1056733fde15f3a8cc349880071f8.bindPopup(popup_caee32602d

# %% [markdown]
# **Do all centuries (with data) have similar results?**
# The clustering patterns appear to show some differences across the centuries.This suggests that the locations of shipwrecks were not entirely consistent over time.
#
# **Does this tell you something about seafaring over time?**
# The changing patterns could indicate shifts in shipping routes, areas of increased trade or conflict, or changes in maritime technology that affected where ships were lost.
#
# **Are all century datasets equally valid for analysis?**
# The datasets are not equally valid for analysis
